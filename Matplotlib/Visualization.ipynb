# %% [markdown]
# # Visualization for company stakeholders

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\Hemant\\Downloads\\file (1).csv")
data.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
loan_status = data['Loan_Status'].value_counts()
loan_status.plot(kind = 'bar')

# %%
#Area type v/s Loan status
property_and_loan = data.groupby(['Property_Area','Loan_Status']).size().unstack()
print(property_and_loan)
# Out:
# Loan_Status     N    Y
# Property_Area
# Rural          68  109
# Semiurban      51  175
# Urban          66  131

# %%
xxx =property_and_loan.plot(kind = 'bar', stacked = False, rot= 45)
xxx.set_xlabel('Property Area')
xxx.set_ylabel('Loan Status')
# Out:
# Text(0, 0.5, 'Loan Status')

# %%
#Stacked - Education v/s Loan Status
education_and_loan = data.groupby(['Education', 'Loan_Status']).size().unstack()
xyz = education_and_loan.plot(kind='bar', stacked = True, rot = 45)
xyz.set_xlabel('Education Status')
xyz.set_ylabel('Loan Status')
# Out:
# Text(0, 0.5, 'Loan Status')

# %%
#Density plot of Loans of Graduates and Not Graduates
graduate = data[data['Education']=='Graduate']
not_graduate = data[data['Education']=='Not Graduate']
graduate['LoanAmount'].plot(kind = 'density', label='Graduate')
not_graduate['LoanAmount'].plot(kind = 'density',label='Not Graduate')

#For automatic legend display
plt.legend()

# %%
#Applicant Income v/s Loan Amount Scatter plot
fig, (ax_1,ax_2,ax_3) = plt.subplots(3,1,figsize=(10,10))
data.plot(x='ApplicantIncome', y ='LoanAmount', kind ='scatter',title = 'Applicant Income',ax=ax_1)

#Coapplicant Income v/s Loan Amount Scatter plot
data.plot(x='CoapplicantIncome', y = 'LoanAmount', kind='scatter',title = 'Coapplicant Income',ax = ax_2)

#Total Income v/s Loan Amount Scatter plot
data['TotalIncome']= data['ApplicantIncome'] + data['CoapplicantIncome']
data.plot(x='TotalIncome',y='LoanAmount',kind ='scatter', title = 'Total Income',ax = ax_3)

# %% [markdown]
# #### Concepts i learnt:
#     Bar plotting
#     Scatter plotting
#     Kernel Density plotting
#     Subplot operations
#     Axes modifications
